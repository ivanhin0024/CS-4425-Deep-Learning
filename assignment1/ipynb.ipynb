# %%
import platform

print(f"I am running on Google's servers: {platform.node()}")
# Out:
# I am running on Google's servers: 6268d9d28e65

# %% [markdown]
# # Local Test Success

# %%
name = input("Enter your name: ") 
print(f"Happy coding, {name}!")
# Out:
# Happy coding, Ivan!
